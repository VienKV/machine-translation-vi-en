# %% [markdown]
# #VI-EN Machine Translation using mBART50 Model
# **Dataset: IWSLT15-en-vi**
#
# **khuongvd00@gmail.com**

# %%
# !nvidia-smi
# Out:
# Wed Mar  1 20:24:03 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    50W / 400W |  15875MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/NLP/machine_translation

# %%
# !pip install -q transformers==4.26.1 sentencepiece==0.1.97 datasets==2.9.0 sacrebleu==2.3.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 53.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 43.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 23.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.2 MB/s eta 0:00:00

# %%
import os
import numpy as np

import sacrebleu

import sentencepiece

import torch
from torch.utils.data import Dataset

from datasets import load_dataset, load_metric
from transformers import *

# %% [markdown]
# ##1.Prepare Data

# %%
class NMTDataset(Dataset):
    def __init__(self, cfg, data_type="train"):
        super().__init__()
        self.cfg = cfg

        self.src_texts, self.tgt_texts = self.read_data(data_type)

        self.src_input_ids = self.texts_to_sequences(self.src_texts)
        self.labels = self.texts_to_sequences(self.tgt_texts)

    def read_data(self, data_type):
        data = load_dataset(
            "mt_eng_vietnamese", 
            "iwslt2015-en-vi", 
            split=data_type
        )
        src_texts = [sample["translation"][self.cfg.src_lang] for sample in data]
        tgt_texts = [sample["translation"][self.cfg.tgt_lang] for sample in data]
        return src_texts, tgt_texts
    
    def texts_to_sequences(self, texts):
        data_inputs = self.cfg.tokenizer(
            texts,
            padding='max_length',
            truncation=True,
            max_length=self.cfg.max_len,
            return_tensors='pt'
        )
        return data_inputs.input_ids

    def __getitem__(self, idx):
        return {
            "input_ids": self.src_input_ids[idx],
            "labels": self.labels[idx]
        }

    def __len__(self):
        return np.shape(self.src_input_ids)[0]

# %% [markdown]
# ##2.Config

# %%
class BaseConfig:
    """ base Encoder Decoder config """

    def __init__(self, **kwargs):
        for k, v in kwargs.items():
            setattr(self, k, v)

class NMTConfig(BaseConfig):
    # Data
    src_lang = 'vi'
    tgt_lang = 'en'
    max_len = 100

    # Model
    model_name = "facebook/mbart-large-50-many-to-many-mmt"

    # Training
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    learning_rate = 5e-5
    train_batch_size = 32
    eval_batch_size = 32
    num_train_epochs = 3
    ckpt_dir = model_name.split('/')[1]
    eval_steps = 500

    # Inference
    beam_size = 5

cfg = NMTConfig()

# %% [markdown]
# ##3.Load Tokenizer and Model

# %%
cfg.tokenizer = MBart50TokenizerFast.from_pretrained(cfg.model_name, src_lang="vi_VN",tgt_lang = "en_XX")
model = MBartForConditionalGeneration.from_pretrained(cfg.model_name)

train_dataset = NMTDataset(cfg, data_type="train")
valid_dataset = NMTDataset(cfg, data_type="validation")
test_dataset = NMTDataset(cfg, data_type="test")

# %% [markdown]
# ##4.Load Metric

# %%
metric = load_metric("sacrebleu")

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = cfg.tokenizer.batch_decode(preds, skip_special_tokens=True)

    decoded_labels = cfg.tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != cfg.tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    
    return result
# Out:
# <ipython-input-11-08c3bcb4979c>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("sacrebleu")
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]

# %% [markdown]
# ##5.Training

# %%
training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    evaluation_strategy="steps",
    save_strategy='steps',
    save_steps=cfg.eval_steps,
    eval_steps=cfg.eval_steps,
    output_dir=cfg.ckpt_dir,
    per_device_train_batch_size=cfg.train_batch_size,
    per_device_eval_batch_size=cfg.eval_batch_size,
    learning_rate=cfg.learning_rate,
    weight_decay=0.005,
    num_train_epochs=cfg.num_train_epochs,
)

data_collator = DataCollatorForSeq2Seq(
    cfg.tokenizer, 
    model=model
)

trainer = Seq2SeqTrainer(
    model,
    training_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    data_collator=data_collator,
    tokenizer=cfg.tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='6001' max='12501' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6001/12501 1:49:31 < 1:58:40, 0.91 it/s, Epoch 1.44/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.594600</td>
#       <td>0.305772</td>
#       <td>35.357500</td>
#       <td>31.048900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.241500</td>
#       <td>0.300835</td>
#       <td>35.636300</td>
#       <td>31.141100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.244500</td>
#       <td>0.300540</td>
#       <td>34.878700</td>
#       <td>31.846300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.243100</td>
#       <td>0.301833</td>
#       <td>35.524000</td>
#       <td>31.129200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.240500</td>
#       <td>0.300886</td>
#       <td>35.966700</td>
#       <td>30.783300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.239800</td>
#       <td>0.297898</td>
#       <td>35.979300</td>
#       <td>31.206500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.238200</td>
#       <td>0.293183</td>
#       <td>36.153400</td>
#       <td>31.269500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.236600</td>
#       <td>0.296028</td>
#       <td>35.387100</td>
#       <td>31.647000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.188300</td>
#       <td>0.318681</td>
#       <td>35.311100</td>
#       <td>30.843200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.167500</td>
#       <td>0.315368</td>
#       <td>36.566900</td>
#       <td>30.637500</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.166900</td>
#       <td>0.318115</td>
#       <td>35.560000</td>
#       <td>31.059900</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.168200</td>
#       <td>0.320043</td>
#       <td>35.126200</td>
#       <td>31.186000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-1500
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-1500/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-1500/generation_config.json
# Model weights saved in mbart-large-50-many-to-many-mmt/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in mbart-large-50-many-to-many-mmt/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in mbart-large-50-many-to-many-mmt/checkpoint-1500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-2000
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-2000/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-2000/generation_config.json
# Model weights saved in mbart-large-50-many-to-many-mmt/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in mbart-large-50-many-to-many-mmt/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in mbart-large-50-many-to-many-mmt/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-2500
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-2500/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-2500/generation_config.json
# Model weights saved in mbart-large-50-many-to-many-mmt/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in mbart-large-50-many-to-many-mmt/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in mbart-large-50-many-to-many-mmt/checkpoint-2500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-3000
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-3000/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-3000/generation_config.json
# Model weights saved in mbart-large-50-many-to-many-mmt/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in mbart-large-50-many-to-many-mmt/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in mbart-large-50-many-to-many-mmt/checkpoint-3000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
# ...
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-5500
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-5500/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-5500/generation_config.json
# Model weights saved in mbart-large-50-many-to-many-mmt/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in mbart-large-50-many-to-many-mmt/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in mbart-large-50-many-to-many-mmt/checkpoint-5500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1269
#   Batch size = 32
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Saving model checkpoint to mbart-large-50-many-to-many-mmt/checkpoint-6000
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-6000/config.json
# Configuration saved in mbart-large-50-many-to-many-mmt/checkpoint-6000/generation_config.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1541             self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1542         )
# -> 1543         return inner_training_loop(
#    1544             args=args,
#    1545             resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1866                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    1867
# -> 1868                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1869                 else:
#    1870                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2133
#    2134         if self.control.should_save:
# -> 2135             self._save_checkpoint(model, trial, metrics=metrics)
#    2136             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    2137
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    2190         run_dir = self._get_output_dir(trial=trial)
#    2191         output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 2192         self.save_model(output_dir, _internal_call=True)
#    2193         if self.deepspeed:
#    2194             # under zero3 model file itself doesn't get saved since it's bogus! Unless deepspeed
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    2669
#    2670         elif self.args.should_save:
# -> 2671             self._save(output_dir)
#    2672
#    2673         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in _save(self, output_dir, state_dict)
#    2721                 torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    2722         else:
# -> 2723             self.model.save_pretrained(output_dir, state_dict=state_dict)
#    2724         if self.tokenizer is not None:
#    2725             self.tokenizer.save_pretrained(output_dir)
#
# /usr/local/lib/python3.8/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, **kwargs)
#    1699                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    1700             else:
# -> 1701                 save_function(shard, os.path.join(save_directory, shard_file))
#    1702
#    1703         if index is None:
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     421     if _use_new_zipfile_serialization:
#     422         with _open_zipfile_writer(f) as opened_zipfile:
# --> 423             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424             return
#     425     else:
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     648         # Now that it is on the CPU we can directly copy it into the zip file
#     649         num_bytes = storage.nbytes()
# --> 650         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     651
#     652
#
# KeyboardInterrupt:

# %% [markdown]
# ##6.Evaluate

# %%
def load_model(cfg, checkpoint_name):
    # Load Tokenizer
    tokenizer = MBart50TokenizerFast.from_pretrained(cfg.model_name, src_lang="vi_VN",tgt_lang = "en_XX")

    # Load Model
    model_save_path = f"{cfg.ckpt_dir}/{checkpoint_name}"
    model = MBartForConditionalGeneration.from_pretrained(model_save_path)

    # Inference Param
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    return tokenizer, model, device

# %%
from tqdm import tqdm
def inference(
    text, 
    src_tokenizer, 
    tgt_tokenizer, 
    model, 
    device="cpu", 
    max_length=75,
    beam_size=5
    ):
    inputs = src_tokenizer(
        text, 
        padding="max_length", 
        truncation=True, 
        max_length=max_length, 
        return_tensors="pt"
        )
    input_ids = inputs.input_ids.to(device)
    attention_mask = inputs.attention_mask.to(device)
    model.to(device)

    outputs = model.generate(
        input_ids, 
        attention_mask=attention_mask, 
        max_length=max_length, 
        early_stopping=True, 
        num_beams=beam_size, 
        length_penalty=2.0
    )

    output_str = tgt_tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return output_str

def inference_bath(
    texts, 
    tokenizer, 
    model, 
    device="cpu", 
    max_length=50,
    beam_size=5,
    batch_size=32
    ):

    pred_texts = []

    if len(texts) < batch_size:
        batch_size = len(texts)

    for x in tqdm(range(0, len(texts), batch_size)):
        text = texts[x:x+batch_size]

        inputs = tokenizer(
            text, 
            padding="max_length", 
            truncation=True, 
            max_length=max_length, 
            return_tensors="pt"
            )
        
        input_ids = inputs.input_ids.to(device)
        attention_mask = inputs.attention_mask.to(device)
        model.to(device)

        outputs = model.generate(
            input_ids, 
            attention_mask=attention_mask, 
            max_length=max_length, 
            early_stopping=True, 
            num_beams=beam_size, 
            length_penalty=2.0
        )

        output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        pred_texts.extend(output_str)
        torch.cuda.empty_cache()

    return pred_texts

# %%
data = load_dataset("mt_eng_vietnamese", "iwslt2015-en-vi", split="test")
src_texts = [sample["translation"]["vi"] for sample in data]
tgt_texts = [sample["translation"]["en"] for sample in data]
# Out:
# WARNING:datasets.builder:Found cached dataset mt_eng_vietnamese (/root/.cache/huggingface/datasets/mt_eng_vietnamese/iwslt2015-en-vi/1.0.0/53add551a01e9874588066f89d42925f9fad43db347199dad00f7e4b0c905a71)

# %% [markdown]
# ###Checkpoint-5000 (Best Valid Bleu_Score)

# %%
tokenizer, model, device = load_model(cfg, checkpoint_name="checkpoint-5000")

# %% [markdown]
# **Beam size = 1**

# %%
pred_texts = inference_bath(src_texts, tokenizer, model, device, beam_size=1)

# %%
sacrebleu.corpus_bleu(pred_texts, [tgt_texts])
# Out:
# BLEU = 31.50 63.8/40.1/28.1/20.3 (BP = 0.906 ratio = 0.910 hyp_len = 25756 ref_len = 28297)

# %% [markdown]
# **Beam size = 5**

# %%
pred_texts = inference_bath(src_texts, tokenizer, model, device)

# %%
sacrebleu.corpus_bleu(pred_texts, [tgt_texts])
# Out:
# BLEU = 33.46 63.4/41.0/29.0/21.1 (BP = 0.942 ratio = 0.943 hyp_len = 26697 ref_len = 28297)

# %% [markdown]
# ###Checkpoint-3500 (Best Valid Loss)

# %%
tokenizer, model, device = load_model(cfg, checkpoint_name="checkpoint-3500")

# %% [markdown]
# **Beam size = 1**

# %%
pred_texts = inference_bath(src_texts, tokenizer, model, device, beam_size=1)

# %%
sacrebleu.corpus_bleu(pred_texts, [tgt_texts])
# Out:
# BLEU = 32.69 64.3/41.3/29.0/20.9 (BP = 0.917 ratio = 0.920 hyp_len = 26041 ref_len = 28297)

# %% [markdown]
# **Beam size = 5**

# %%
pred_texts = inference_bath(src_texts, tokenizer, model, device)

# %%
sacrebleu.corpus_bleu(pred_texts, [tgt_texts])
# Out:
# BLEU = 34.07 62.8/40.9/29.1/21.2 (BP = 0.960 ratio = 0.961 hyp_len = 27185 ref_len = 28297)
